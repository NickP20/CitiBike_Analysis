# %%
import pandas as pd

# %%
df1 = pd.read_csv('202007-citibike-tripdata.csv')
df2 = pd.read_csv('202008-citibike-tripdata.csv')
df3 = pd.read_csv('202009-citibike-tripdata.csv')
df4 = pd.read_csv('202010-citibike-tripdata.csv')
df5 = pd.read_csv('202011-citibike-tripdata.csv')
df6 = pd.read_csv('202012-citibike-tripdata.csv')

# %%
Q3_4_df = pd.concat([df1, df2, df3, df4, df5, df6])
Q3_4_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 341  2020-07-01 00:00:01.3020  2020-07-01 00:05:42.5650
# 1                 321  2020-07-01 00:00:01.3620  2020-07-01 00:05:22.9490
# 2                2710  2020-07-01 00:00:06.6290  2020-07-01 00:45:17.3410
# 3                2685  2020-07-01 00:00:13.0220  2020-07-01 00:44:58.8640
# 4                 191  2020-07-01 00:00:13.4660  2020-07-01 00:03:24.6230
# ...               ...                       ...                       ...
# 1088924          2045  2020-12-31 23:58:21.7040  2021-01-01 00:32:27.1570
# 1088925           288  2020-12-31 23:58:37.8400  2021-01-01 00:03:26.3250
# 1088926           152  2020-12-31 23:58:52.8090  2021-01-01 00:01:25.6720
# 1088927           654  2020-12-31 23:59:55.9550  2021-01-01 00:10:50.6050
# 1088928          2589  2020-12-31 23:59:57.4070  2021-01-01 00:43:06.4490
#
#          start station id                   start station name  \
# ...

# %%
Q3_4_df.to_csv('Q3_4.csv')

# %%
duplicate = Q3_4_df[Q3_4_df.duplicated()]

# %%
duplicate
# Out:
# Empty DataFrame
# Columns: [tripduration, starttime, stoptime, start station id, start station name, start station latitude, start station longitude, end station id, end station name, end station latitude, end station longitude, bikeid, usertype, birth year, gender]
# Index: []

# %%
age = pd.DataFrame(Q3_4_df, columns = ['birth year', 'starttime'])

# %%
age.loc[age['birth year'] == 1969]
# Out:
#          birth year                 starttime
# 2              1969  2020-07-01 00:00:06.6290
# 12             1969  2020-07-01 00:00:53.3270
# 14             1969  2020-07-01 00:00:56.8880
# 16             1969  2020-07-01 00:01:00.4910
# 17             1969  2020-07-01 00:01:00.9970
# ...             ...                       ...
# 1088903        1969  2020-12-31 23:54:49.7470
# 1088915        1969  2020-12-31 23:57:17.1180
# 1088925        1969  2020-12-31 23:58:37.8400
# 1088926        1969  2020-12-31 23:58:52.8090
# 1088928        1969  2020-12-31 23:59:57.4070
#
# [1445020 rows x 2 columns]
